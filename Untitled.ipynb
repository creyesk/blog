# %%
import numpy as np 
import matplotlib.pyplot as plt

x = np.linspace(0,10000000, 1000)
plt.plot(x, np.log(x))
# plt.plot(x, 10*x**1.1)
plt.show()
# Out:
# /home/carlos/venv/datascience/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log
#   """
